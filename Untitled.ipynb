# %%
import numpy as np
import pandas as pd
import pickle
import sys
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


def load_file(path):
    with open(path, 'rb') as f:

        file = pickle.load(f)

        if type(file) is not np.ndarray:
            file = np.array(file)

        return file

X = load_file(r'/Users/sushenzhang/Documents/phd/second_year_code/X_values.pkl')
y = load_file(r'/Users/sushenzhang/Documents/phd/second_year_code/Y_values.pkl')
X = (X-X.min())/(X.max()-X.min())
y= (y-y.min())/(y.max()-y.min())

y = y[:,[0,1,3]]
df=pd.DataFrame(y)
corr=df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_2ae86036_87f1_11ea_a7f6_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2ae86036_87f1_11ea_a7f6_acde48001122row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2ae86036_87f1_11ea_a7f6_acde48001122row0_col2 {
#             background-color:  #f29274;
#             color:  #000000;
#         }    #T_2ae86036_87f1_11ea_a7f6_acde48001122row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2ae86036_87f1_11ea_a7f6_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2ae86036_87f1_11ea_a7f6_acde48001122row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2ae86036_87f1_11ea_a7f6_acde48001122row2_col0 {
#             background-color:  #ef886b;
#             color:  #000000;
# ...

# %%
py=y[:,1]
px=X[:,3]
plt.scatter(px,py)

# %%
import pandas as pd

df_oil=pd.read_csv('./full.csv')
y=df_oil[['average_speed','average_number_of_droplets_last_second','max_average_single_droplet_speed','average_number_of_droplets']]

# %%
df_oil_y=pd.DataFrame(y)
corr=df_oil_y.corr()
corr.style.background_gradient(cmap='Accent')
# Out:
# <style  type="text/css" >
#     #T_c8c6b3b8_8731_11ea_b9b2_aae9fe7dd2d0row0_col0 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_c8c6b3b8_8731_11ea_b9b2_aae9fe7dd2d0row0_col1 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_c8c6b3b8_8731_11ea_b9b2_aae9fe7dd2d0row0_col2 {
#             background-color:  #bf5b17;
#             color:  #000000;
#         }    #T_c8c6b3b8_8731_11ea_b9b2_aae9fe7dd2d0row0_col3 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_c8c6b3b8_8731_11ea_b9b2_aae9fe7dd2d0row1_col0 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_c8c6b3b8_8731_11ea_b9b2_aae9fe7dd2d0row1_col1 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_c8c6b3b8_8731_11ea_b9b2_aae9fe7dd2d0row1_col2 {
#             background-color:  #7fc97f;
#             color:  #000000;
# ...

# %%
df_oil
# Out:
#                                                     path       dep   octanol  \
# 0      /home/group/orkney1/Chemobot/dropfactory_explo...  0.260665  0.524919
# 1      /home/group/orkney1/Chemobot/dropfactory_explo...  0.366671  0.298558
# 2      /home/group/orkney1/Chemobot/dropfactory_explo...  0.467282  0.053418
# 3      /home/group/orkney1/Chemobot/dropfactory_explo...  0.479186  0.134630
# 4      /home/group/orkney1/Chemobot/dropfactory_explo...  0.409956  0.449119
# 5      /home/group/orkney1/Chemobot/dropfactory_explo...  0.198717  0.254031
# 6      /home/group/orkney1/Chemobot/dropfactory_explo...  0.463373  0.000668
# 7      /home/group/orkney1/Chemobot/dropfactory_explo...  0.499629  0.114725
# 8      /home/group/orkney1/Chemobot/dropfactory_explo...  0.315815  0.474471
# 9      /home/group/orkney1/Chemobot/dropfactory_explo...  0.320496  0.530079
# 10     /home/group/orkney1/Chemobot/dropfactory_explo...  0.046452  0.511732
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df_oil['average_speed'], df_oil['max_average_single_droplet_speed'])
